# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
   
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 591

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
#url = "https://api.openweathermap.org/data/3.0/onecall"
#?lat={lat}&lon={lon}&appid={API key}
url = "https://api.openweathermap.org/data/2.5/weather/?"
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
   
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    #city_url =  YOUR CODE HERE
    city_url = url + "q=" + city +"&appid=" + weather_api_key
    response = requests.get(city_url)
    response_json = response.json()
   
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = response_json["weather"]
            
        # YOUR CODE HERE

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = response_json['coord']['lat']
        city_lng = response_json['coord']['lon']
        city_max_temp = response_json['main']['temp_max']
        city_humidity = response_json['main']['humidity']
        city_clouds = response_json['clouds']['all']
        city_wind = response_json['wind']['speed']
        city_country = response_json['sys']['country']
        city_date = response_json["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | afif
# Processing Record 2 of Set 1 | mek'ele
# Processing Record 3 of Set 1 | waitangi
# Processing Record 4 of Set 1 | mahina
# Processing Record 5 of Set 1 | college
# Processing Record 6 of Set 1 | tiksi
# Processing Record 7 of Set 1 | saipan
# Processing Record 8 of Set 1 | newman
# Processing Record 9 of Set 1 | moranbah
# Processing Record 10 of Set 1 | adamstown
# Processing Record 11 of Set 1 | klaksvik
# Processing Record 12 of Set 1 | malvan
# Processing Record 13 of Set 1 | bethel
# Processing Record 14 of Set 1 | vadso
# Processing Record 15 of Set 1 | antofagasta
# Processing Record 16 of Set 1 | port shepstone
# Processing Record 17 of Set 1 | margaret river
# Processing Record 18 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 19 of Set 1 | wailua homesteads
# Processing Record 20 of Set 1 | port-aux-francais
# Processing Record 21 of Set 1 | isafjordur
# Processing Record 22 of Set 1 | zaozersk
# Processing Record 23 of Set 1 | isla mujeres
# Processing Record 24 of Set 1 | minas de marcona
# Processing Record 25 of Set 1 | polovinnoye
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | uturoa
# Processing Record 28 of Set 1 | wanning
# Processing Record 29 of Set 1 | el calafate
# Processing Record 30 of Set 1 | san antonio
# Processing Record 31 of Set 1 | puerto natales
# Processing Record 32 of Set 1 | grytviken
# Processing Record 33 of Set 1 | ancud
# Processing Record 34 of Set 1 | blackmans bay
# Processing Record 35 of Set 1 | tandil
# Processing Record 36 of Set 1 | susanville
# Processing Record 37 of Set 1 | ribeira grande
# Processing Record 38 of Set 1 | constantia
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | san patricio
# Processing Record 41 of Set 1 | mitu
# Processing Record 42 of Set 1 | toga village
# City not found. Skipping...
# Processing Record 43 of Set 1 | prainha
# Processing Record 44 of Set 1 | gurupa
# Processing Record 45 of Set 1 | vila franca do campo
# Processing Record 46 of Set 1 | ust-nera
# Processing Record 47 of Set 1 | saldanha
# Processing Record 48 of Set 1 | edinburgh of the seven seas
# Processing Record 49 of Set 1 | kourou
# Processing Record 50 of Set 1 | kifri
# Processing Record 0 of Set 2 | albany
# Processing Record 1 of Set 2 | brokopondo
# Processing Record 2 of Set 2 | crane
# Processing Record 3 of Set 2 | naze
# Processing Record 4 of Set 2 | whitehorse
# Processing Record 5 of Set 2 | mana
# Processing Record 6 of Set 2 | iqaluit
# Processing Record 7 of Set 2 | pokhara
# Processing Record 8 of Set 2 | badger
# Processing Record 9 of Set 2 | cafayate
# Processing Record 10 of Set 2 | ushuaia
# Processing Record 11 of Set 2 | iskateley
# Processing Record 12 of Set 2 | tymovskoye
# Processing Record 13 of Set 2 | avarua
# Processing Record 14 of Set 2 | west island
# Processing Record 15 of Set 2 | carnarvon
# Processing Record 16 of Set 2 | khorixas
# Processing Record 17 of Set 2 | fisterra
# Processing Record 18 of Set 2 | kingston
# Processing Record 19 of Set 2 | vorkuta
# Processing Record 20 of Set 2 | callao
# Processing Record 21 of Set 2 | kerman
# Processing Record 22 of Set 2 | quellon
# Processing Record 23 of Set 2 | st. john's
# Processing Record 24 of Set 2 | east end
# Processing Record 25 of Set 2 | cill airne
# Processing Record 26 of Set 2 | lagos
# Processing Record 27 of Set 2 | gadzhiyevo
# Processing Record 28 of Set 2 | port elizabeth
# Processing Record 29 of Set 2 | ringsted
# Processing Record 30 of Set 2 | ain bessem
# Processing Record 31 of Set 2 | karratha
# Processing Record 32 of Set 2 | glendive
# Processing Record 33 of Set 2 | kuqa
# Processing Record 34 of Set 2 | bilibino
# Processing Record 35 of Set 2 | bonito
# Processing Record 36 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 37 of Set 2 | kota
# Processing Record 38 of Set 2 | kincardine
# Processing Record 39 of Set 2 | banda aceh
# Processing Record 40 of Set 2 | tazovsky
# Processing Record 41 of Set 2 | fort riley north
# Processing Record 42 of Set 2 | invercargill
# Processing Record 43 of Set 2 | la passe
# Processing Record 44 of Set 2 | georgetown
# Processing Record 45 of Set 2 | ilulissat
# Processing Record 46 of Set 2 | daru
# Processing Record 47 of Set 2 | port mathurin
# Processing Record 48 of Set 2 | sitka
# Processing Record 49 of Set 2 | balcarce
# Processing Record 0 of Set 3 | nishinoomote
# Processing Record 1 of Set 3 | mandalgovi
# Processing Record 2 of Set 3 | itaituba
# Processing Record 3 of Set 3 | bredasdorp
# Processing Record 4 of Set 3 | hobyo
# Processing Record 5 of Set 3 | illela
# Processing Record 6 of Set 3 | cutral-co
# Processing Record 7 of Set 3 | al shamkhah city
# City not found. Skipping...
# Processing Record 8 of Set 3 | monte santo de minas
# Processing Record 9 of Set 3 | sao vicente
# Processing Record 10 of Set 3 | isangel
# Processing Record 11 of Set 3 | luderitz
# Processing Record 12 of Set 3 | hawaiian paradise park
# Processing Record 13 of Set 3 | haiku-pauwela
# Processing Record 14 of Set 3 | ola
# Processing Record 15 of Set 3 | yellowknife
# Processing Record 16 of Set 3 | kapuskasing
# Processing Record 17 of Set 3 | remire-montjoly
# Processing Record 18 of Set 3 | stanley
# Processing Record 19 of Set 3 | nar'yan-mar
# Processing Record 20 of Set 3 | vryburg
# Processing Record 21 of Set 3 | anloga
# Processing Record 22 of Set 3 | fale old settlement
# Processing Record 23 of Set 3 | chonchi
# Processing Record 24 of Set 3 | new norfolk
# Processing Record 25 of Set 3 | gallivare
# City not found. Skipping...
# Processing Record 26 of Set 3 | dobeln
# Processing Record 27 of Set 3 | nogliki
# Processing Record 28 of Set 3 | yanji
# Processing Record 29 of Set 3 | afaahiti
# Processing Record 30 of Set 3 | papatowai
# Processing Record 31 of Set 3 | bandarbeyla
# Processing Record 32 of Set 3 | broceni
# Processing Record 33 of Set 3 | duncan town
# City not found. Skipping...
# Processing Record 34 of Set 3 | palikir - national government center
# Processing Record 35 of Set 3 | nadi
# Processing Record 36 of Set 3 | riosucio
# Processing Record 37 of Set 3 | klyuchi
# Processing Record 38 of Set 3 | talnakh
# Processing Record 39 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 40 of Set 3 | sanming
# Processing Record 41 of Set 3 | vallenar
# Processing Record 42 of Set 3 | christchurch
# Processing Record 43 of Set 3 | puerto baquerizo moreno
# Processing Record 44 of Set 3 | uray
# Processing Record 45 of Set 3 | bubaque
# Processing Record 46 of Set 3 | bamboo flat
# Processing Record 47 of Set 3 | wynyard
# Processing Record 48 of Set 3 | broken hill
# Processing Record 49 of Set 3 | murun-kuren
# Processing Record 0 of Set 4 | luanda
# Processing Record 1 of Set 4 | flying fish cove
# Processing Record 2 of Set 4 | benguela
# Processing Record 3 of Set 4 | turpan
# Processing Record 4 of Set 4 | punta arenas
# Processing Record 5 of Set 4 | thompson
# Processing Record 6 of Set 4 | naryn
# Processing Record 7 of Set 4 | cable beach
# City not found. Skipping...
# Processing Record 8 of Set 4 | rostovka
# Processing Record 9 of Set 4 | dunedin
# Processing Record 10 of Set 4 | codrington
# Processing Record 11 of Set 4 | freeport
# Processing Record 12 of Set 4 | raychikhinsk
# Processing Record 13 of Set 4 | la malbaie
# Processing Record 14 of Set 4 | mount gambier
# Processing Record 15 of Set 4 | kenai
# Processing Record 16 of Set 4 | selfoss
# Processing Record 17 of Set 4 | prachuap khiri khan
# Processing Record 18 of Set 4 | lihue
# Processing Record 19 of Set 4 | bouarfa
# Processing Record 20 of Set 4 | beledweyne
# Processing Record 21 of Set 4 | egilsstadir
# Processing Record 22 of Set 4 | forster
# Processing Record 23 of Set 4 | kiunga
# Processing Record 24 of Set 4 | vredenburg
# City not found. Skipping...
# Processing Record 25 of Set 4 | isle of lewis
# City not found. Skipping...
# Processing Record 26 of Set 4 | chajari
# Processing Record 27 of Set 4 | alenquer
# Processing Record 28 of Set 4 | darwin
# Processing Record 29 of Set 4 | san antonio de pale
# Processing Record 30 of Set 4 | sisimiut
# Processing Record 31 of Set 4 | cabo san lucas
# Processing Record 32 of Set 4 | utrik
# Processing Record 33 of Set 4 | martapura
# Processing Record 34 of Set 4 | benjamin constant
# Processing Record 35 of Set 4 | udachny
# Processing Record 36 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 37 of Set 4 | chernyshevskiy
# Processing Record 38 of Set 4 | tolanaro
# Processing Record 39 of Set 4 | rabigh
# Processing Record 40 of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 41 of Set 4 | dudinka
# Processing Record 42 of Set 4 | vilyuysk
# Processing Record 43 of Set 4 | leshan
# Processing Record 44 of Set 4 | polyarnyy
# Processing Record 45 of Set 4 | nemuro
# Processing Record 46 of Set 4 | andovoranto
# Processing Record 47 of Set 4 | katsuura
# Processing Record 48 of Set 4 | arraial do cabo
# Processing Record 49 of Set 4 | moron
# Processing Record 0 of Set 5 | nova sintra
# Processing Record 1 of Set 5 | aripuana
# Processing Record 2 of Set 5 | savave village
# City not found. Skipping...
# Processing Record 3 of Set 5 | shimoda
# Processing Record 4 of Set 5 | el bauga
# Processing Record 5 of Set 5 | laguna
# Processing Record 6 of Set 5 | longyearbyen
# Processing Record 7 of Set 5 | dakhla
# Processing Record 8 of Set 5 | mount isa
# Processing Record 9 of Set 5 | west lafayette
# Processing Record 10 of Set 5 | conduaga
# Processing Record 11 of Set 5 | krosno odrzanskie
# Processing Record 12 of Set 5 | el estor
# Processing Record 13 of Set 5 | luau
# Processing Record 14 of Set 5 | pisco
# Processing Record 15 of Set 5 | labytnangi
# Processing Record 16 of Set 5 | solwezi
# Processing Record 17 of Set 5 | holualoa
# Processing Record 18 of Set 5 | enewetak
# Processing Record 19 of Set 5 | huarmey
# Processing Record 20 of Set 5 | tandalti
# Processing Record 21 of Set 5 | socorro
# Processing Record 22 of Set 5 | ghadamis
# Processing Record 23 of Set 5 | sandnessjoen
# Processing Record 24 of Set 5 | bayan nur
# City not found. Skipping...
# Processing Record 25 of Set 5 | mazamari
# Processing Record 26 of Set 5 | pariaman
# Processing Record 27 of Set 5 | carutapera
# Processing Record 28 of Set 5 | alice springs
# Processing Record 29 of Set 5 | weno
# Processing Record 30 of Set 5 | constitucion
# Processing Record 31 of Set 5 | atar
# Processing Record 32 of Set 5 | vila velha
# Processing Record 33 of Set 5 | labrador city
# Processing Record 34 of Set 5 | shofirkon shahri
# City not found. Skipping...
# Processing Record 35 of Set 5 | zambezi
# Processing Record 36 of Set 5 | funafuti
# Processing Record 37 of Set 5 | sidrolandia
# Processing Record 38 of Set 5 | olonkinbyen
# Processing Record 39 of Set 5 | kodiak
# Processing Record 40 of Set 5 | argo
# Processing Record 41 of Set 5 | mitsamiouli
# Processing Record 42 of Set 5 | colonia
# Processing Record 43 of Set 5 | lebu
# Processing Record 44 of Set 5 | hirara
# Processing Record 45 of Set 5 | cole harbour
# Processing Record 46 of Set 5 | kununurra
# Processing Record 47 of Set 5 | hit
# Processing Record 48 of Set 5 | de aar
# Processing Record 49 of Set 5 | taltal
# Processing Record 0 of Set 6 | qaqortoq
# Processing Record 1 of Set 6 | buka
# Processing Record 2 of Set 6 | gaiman
# Processing Record 3 of Set 6 | hammerfest
# Processing Record 4 of Set 6 | harper
# Processing Record 5 of Set 6 | vikulovo
# Processing Record 6 of Set 6 | hovd
# Processing Record 7 of Set 6 | tura
# Processing Record 8 of Set 6 | ghat
# Processing Record 9 of Set 6 | waslala
# Processing Record 10 of Set 6 | atafu village
# Processing Record 11 of Set 6 | punta alta
# Processing Record 12 of Set 6 | nchelenge
# Processing Record 13 of Set 6 | pocone
# Processing Record 14 of Set 6 | kralendijk
# Processing Record 15 of Set 6 | sakakah
# Processing Record 16 of Set 6 | yemva
# Processing Record 17 of Set 6 | sittwe
# Processing Record 18 of Set 6 | nouadhibou
# Processing Record 19 of Set 6 | rio grande city
# Processing Record 20 of Set 6 | mount pearl
# Processing Record 21 of Set 6 | revda
# Processing Record 22 of Set 6 | berezovyy
# Processing Record 23 of Set 6 | nagqu
# Processing Record 24 of Set 6 | saint-francois
# Processing Record 25 of Set 6 | vernon
# Processing Record 26 of Set 6 | rawson
# Processing Record 27 of Set 6 | bouna
# Processing Record 28 of Set 6 | fyodorovka
# Processing Record 29 of Set 6 | buala
# Processing Record 30 of Set 6 | baikonur
# Processing Record 31 of Set 6 | chechelnyk
# Processing Record 32 of Set 6 | hamilton
# Processing Record 33 of Set 6 | torrington
# Processing Record 34 of Set 6 | onega
# Processing Record 35 of Set 6 | korla
# Processing Record 36 of Set 6 | natal
# Processing Record 37 of Set 6 | kot mumin
# Processing Record 38 of Set 6 | jayapura
# Processing Record 39 of Set 6 | rongelap
# Processing Record 40 of Set 6 | harnosand
# Processing Record 41 of Set 6 | kimberley
# Processing Record 42 of Set 6 | saint-philippe
# Processing Record 43 of Set 6 | berdigestyakh
# Processing Record 44 of Set 6 | qianzhou
# Processing Record 45 of Set 6 | juan griego
# Processing Record 46 of Set 6 | pangoa
# Processing Record 47 of Set 6 | puerto san carlos
# City not found. Skipping...
# Processing Record 48 of Set 6 | iaciara
# Processing Record 49 of Set 6 | mont-laurier
# Processing Record 0 of Set 7 | namibe
# Processing Record 1 of Set 7 | bodaybo
# Processing Record 2 of Set 7 | nayoro
# Processing Record 3 of Set 7 | megion
# Processing Record 4 of Set 7 | cambria
# Processing Record 5 of Set 7 | kavaratti
# Processing Record 6 of Set 7 | la'ie
# Processing Record 7 of Set 7 | axim
# Processing Record 8 of Set 7 | la mira
# Processing Record 9 of Set 7 | embi
# Processing Record 10 of Set 7 | piet retief
# Processing Record 11 of Set 7 | khemisset
# Processing Record 12 of Set 7 | tibanbang
# Processing Record 13 of Set 7 | undurkhaan
# Processing Record 14 of Set 7 | tralee
# Processing Record 15 of Set 7 | al hazm
# Processing Record 16 of Set 7 | zvishavane
# Processing Record 17 of Set 7 | khandyga
# Processing Record 18 of Set 7 | youghal
# Processing Record 19 of Set 7 | bontang
# Processing Record 20 of Set 7 | okhotsk
# Processing Record 21 of Set 7 | deschutes river woods
# Processing Record 22 of Set 7 | sidi bennour
# Processing Record 23 of Set 7 | al kharijah
# Processing Record 24 of Set 7 | katsuren-haebaru
# Processing Record 25 of Set 7 | gilroy
# Processing Record 26 of Set 7 | vorgashor
# Processing Record 27 of Set 7 | bomdila
# Processing Record 28 of Set 7 | ulanhot
# Processing Record 29 of Set 7 | chato
# Processing Record 30 of Set 7 | cueibet
# City not found. Skipping...
# Processing Record 31 of Set 7 | kostomuksha
# Processing Record 32 of Set 7 | chengde
# Processing Record 33 of Set 7 | santa ana
# Processing Record 34 of Set 7 | bartica
# Processing Record 35 of Set 7 | susuman
# Processing Record 36 of Set 7 | parabel'
# Processing Record 37 of Set 7 | queenstown
# Processing Record 38 of Set 7 | juigalpa
# Processing Record 39 of Set 7 | hun
# Processing Record 40 of Set 7 | arteche
# Processing Record 41 of Set 7 | amuntai
# Processing Record 42 of Set 7 | antsiranana
# Processing Record 43 of Set 7 | melekhovo
# Processing Record 44 of Set 7 | yinchuan
# Processing Record 45 of Set 7 | czarne
# Processing Record 46 of Set 7 | acarau
# Processing Record 47 of Set 7 | boende
# Processing Record 48 of Set 7 | tsiombe
# Processing Record 49 of Set 7 | fort mcmurray
# Processing Record 0 of Set 8 | mahenge
# Processing Record 1 of Set 8 | ayaguz
# City not found. Skipping...
# Processing Record 2 of Set 8 | saudarkrokur
# Processing Record 3 of Set 8 | pemangkat
# Processing Record 4 of Set 8 | az zawr
# Processing Record 5 of Set 8 | lorengau
# Processing Record 6 of Set 8 | jamestown
# Processing Record 7 of Set 8 | nuuk
# Processing Record 8 of Set 8 | san marcos
# Processing Record 9 of Set 8 | sur
# Processing Record 10 of Set 8 | mayqayyng
# Processing Record 11 of Set 8 | road town
# Processing Record 12 of Set 8 | arawa
# Processing Record 13 of Set 8 | pak phanang
# Processing Record 14 of Set 8 | rio grande
# Processing Record 15 of Set 8 | borgarnes
# Processing Record 16 of Set 8 | vera cruz
# Processing Record 17 of Set 8 | papao
# Processing Record 18 of Set 8 | mejit
# Processing Record 19 of Set 8 | barcelos
# Processing Record 20 of Set 8 | lompoc
# Processing Record 21 of Set 8 | keflavik
# Processing Record 22 of Set 8 | ballina
# Processing Record 23 of Set 8 | la gi
# Processing Record 24 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 25 of Set 8 | aasiaat
# Processing Record 26 of Set 8 | tshabong
# Processing Record 27 of Set 8 | takoradi
# Processing Record 28 of Set 8 | naraina
# Processing Record 29 of Set 8 | usinsk
# Processing Record 30 of Set 8 | herval
# Processing Record 31 of Set 8 | san luis
# Processing Record 32 of Set 8 | nuku'alofa
# Processing Record 33 of Set 8 | tobi village
# City not found. Skipping...
# Processing Record 34 of Set 8 | edinboro
# Processing Record 35 of Set 8 | bandundu
# Processing Record 36 of Set 8 | cumana
# Processing Record 37 of Set 8 | magadan
# Processing Record 38 of Set 8 | barra de santo antonio
# Processing Record 39 of Set 8 | indian hills
# Processing Record 40 of Set 8 | yaren
# Processing Record 41 of Set 8 | hasaki
# Processing Record 42 of Set 8 | beidao
# Processing Record 43 of Set 8 | padegan-e manjil
# City not found. Skipping...
# Processing Record 44 of Set 8 | dryden
# Processing Record 45 of Set 8 | thinadhoo
# Processing Record 46 of Set 8 | richards bay
# Processing Record 47 of Set 8 | hithadhoo
# Processing Record 48 of Set 8 | safford
# Processing Record 49 of Set 8 | ambodivoara
# City not found. Skipping...
# Processing Record 0 of Set 9 | sungai besar
# Processing Record 1 of Set 9 | krasnovishersk
# Processing Record 2 of Set 9 | shepetivka
# Processing Record 3 of Set 9 | az zuwaytinah
# Processing Record 4 of Set 9 | caldas novas
# Processing Record 5 of Set 9 | hami
# Processing Record 6 of Set 9 | tangalle
# Processing Record 7 of Set 9 | maych'ew
# Processing Record 8 of Set 9 | grand falls-windsor
# Processing Record 9 of Set 9 | piranhas
# Processing Record 10 of Set 9 | mahibadhoo
# Processing Record 11 of Set 9 | san-pedro
# Processing Record 12 of Set 9 | puerto leguizamo
# Processing Record 13 of Set 9 | essaouira
# Processing Record 14 of Set 9 | port hedland
# Processing Record 15 of Set 9 | awash
# Processing Record 16 of Set 9 | nhamunda
# Processing Record 17 of Set 9 | tres arroyos
# Processing Record 18 of Set 9 | inhambane
# Processing Record 19 of Set 9 | olgii
# City not found. Skipping...
# Processing Record 20 of Set 9 | gisborne
# Processing Record 21 of Set 9 | red hill
# Processing Record 22 of Set 9 | guerrero negro
# Processing Record 23 of Set 9 | vilyuchinsk
# Processing Record 24 of Set 9 | kidal
# Processing Record 25 of Set 9 | vingt cinq
# City not found. Skipping...
# Processing Record 26 of Set 9 | alta
# Processing Record 27 of Set 9 | al quwayrah
# Processing Record 28 of Set 9 | padang
# Processing Record 29 of Set 9 | palmer
# Processing Record 30 of Set 9 | roata de jos
# Processing Record 31 of Set 9 | faya-largeau
# Processing Record 32 of Set 9 | kristiansund
# Processing Record 33 of Set 9 | rikaze
# Processing Record 34 of Set 9 | praia da vitoria
# Processing Record 35 of Set 9 | malabar
# Processing Record 36 of Set 9 | aroma
# Processing Record 37 of Set 9 | williams lake
# Processing Record 38 of Set 9 | arafat
# Processing Record 39 of Set 9 | cooma
# Processing Record 40 of Set 9 | mutuali
# Processing Record 41 of Set 9 | tidjikja
# Processing Record 42 of Set 9 | dalandzadgad
# Processing Record 43 of Set 9 | sinabang
# Processing Record 44 of Set 9 | maxixe
# Processing Record 45 of Set 9 | gonzaga
# Processing Record 46 of Set 9 | el colomo
# Processing Record 47 of Set 9 | biasca
# Processing Record 48 of Set 9 | kashin
# Processing Record 49 of Set 9 | arica
# Processing Record 0 of Set 10 | same
# Processing Record 1 of Set 10 | kalevala
# Processing Record 2 of Set 10 | yichun
# Processing Record 3 of Set 10 | makhambet
# Processing Record 4 of Set 10 | tadmur
# Processing Record 5 of Set 10 | olyokminsk
# Processing Record 6 of Set 10 | timimoun
# Processing Record 7 of Set 10 | volodarskiy
# Processing Record 8 of Set 10 | kraksaan
# Processing Record 9 of Set 10 | castillos
# Processing Record 10 of Set 10 | taroa
# Processing Record 11 of Set 10 | mpongwe
# Processing Record 12 of Set 10 | leh
# Processing Record 13 of Set 10 | coahuayana de hidalgo
# Processing Record 14 of Set 10 | los llanos de aridane
# Processing Record 15 of Set 10 | aglona
# Processing Record 16 of Set 10 | qasr-e qand
# City not found. Skipping...
# Processing Record 17 of Set 10 | veinticinco de mayo
# Processing Record 18 of Set 10 | hilo
# Processing Record 19 of Set 10 | lazaro cardenas
# Processing Record 20 of Set 10 | celestun
# Processing Record 21 of Set 10 | stephenville
# Processing Record 22 of Set 10 | tahlequah
# Processing Record 23 of Set 10 | dwarka
# Processing Record 24 of Set 10 | toliara
# Processing Record 25 of Set 10 | ust'-ilimsk
# Processing Record 26 of Set 10 | zeya
# Processing Record 27 of Set 10 | lashio
# Processing Record 28 of Set 10 | green river
# Processing Record 29 of Set 10 | chacabuco
# Processing Record 30 of Set 10 | anadyr
# Processing Record 31 of Set 10 | naousa
# Processing Record 32 of Set 10 | caucete
# Processing Record 33 of Set 10 | santa cruz
# Processing Record 34 of Set 10 | howrah
# Processing Record 35 of Set 10 | bela
# Processing Record 36 of Set 10 | gueltat zemmour
# City not found. Skipping...
# Processing Record 37 of Set 10 | dhidhdhoo
# Processing Record 38 of Set 10 | vandergrift
# Processing Record 39 of Set 10 | tashtagol
# Processing Record 40 of Set 10 | east ballina
# Processing Record 41 of Set 10 | merced
# Processing Record 42 of Set 10 | cumnock
# Processing Record 43 of Set 10 | manakara
# Processing Record 44 of Set 10 | uchaly
# Processing Record 45 of Set 10 | puerto palomas
# Processing Record 46 of Set 10 | bentiu
# Processing Record 47 of Set 10 | sola
# Processing Record 48 of Set 10 | vung tau
# Processing Record 49 of Set 10 | port alfred
# Processing Record 0 of Set 11 | robore
# Processing Record 1 of Set 11 | hanko
# Processing Record 2 of Set 11 | ponta delgada
# Processing Record 3 of Set 11 | we
# City not found. Skipping...
# Processing Record 4 of Set 11 | den burg
# Processing Record 5 of Set 11 | elmendorf air force base
# City not found. Skipping...
# Processing Record 6 of Set 11 | yuzhno-kurilsk
# Processing Record 7 of Set 11 | ketchikan
# Processing Record 8 of Set 11 | brookings
# Processing Record 9 of Set 11 | bambanglipuro
# Processing Record 10 of Set 11 | belmonte
# Processing Record 11 of Set 11 | koundara
# Processing Record 12 of Set 11 | bonthe
# Processing Record 13 of Set 11 | puttalam
# Processing Record 14 of Set 11 | livani
# Processing Record 15 of Set 11 | hermantown
# Processing Record 16 of Set 11 | ta`u
# Processing Record 17 of Set 11 | port glaud
# City not found. Skipping...
# Processing Record 18 of Set 11 | altay
# Processing Record 19 of Set 11 | mugumu
# Processing Record 20 of Set 11 | al jawf
# Processing Record 21 of Set 11 | ad dujayl
# Processing Record 22 of Set 11 | uliastay
# Processing Record 23 of Set 11 | south chicago
# City not found. Skipping...
# Processing Record 24 of Set 11 | madera
# Processing Record 25 of Set 11 | adiake
# Processing Record 26 of Set 11 | coeur d'alene
# Processing Record 27 of Set 11 | sao paulo de olivenca
# Processing Record 28 of Set 11 | kalymnos
# Processing Record 29 of Set 11 | boca suno
# Processing Record 30 of Set 11 | masterton
# Processing Record 31 of Set 11 | fort st. john
# Processing Record 32 of Set 11 | as sulayyil
# Processing Record 33 of Set 11 | manokwari
# Processing Record 34 of Set 11 | al hawatah
# Processing Record 35 of Set 11 | tanjung pandan
# Processing Record 36 of Set 11 | abraham's bay
# City not found. Skipping...
# Processing Record 37 of Set 11 | reggane
# Processing Record 38 of Set 11 | necochea
# Processing Record 39 of Set 11 | talcahuano
# Processing Record 40 of Set 11 | margate
# Processing Record 41 of Set 11 | handan
# Processing Record 42 of Set 11 | aswan
# Processing Record 43 of Set 11 | villa gesell
# Processing Record 44 of Set 11 | fort bragg
# Processing Record 45 of Set 11 | al-`ula
# City not found. Skipping...
# Processing Record 46 of Set 11 | male
# Processing Record 47 of Set 11 | puerto armuelles
# Processing Record 48 of Set 11 | verkhnevilyuysk
# Processing Record 49 of Set 11 | kavieng
# Processing Record 0 of Set 12 | spring valley
# Processing Record 1 of Set 12 | charters towers
# Processing Record 2 of Set 12 | ribnica
# Processing Record 3 of Set 12 | sormiou
# City not found. Skipping...
# Processing Record 4 of Set 12 | marrakesh
# Processing Record 5 of Set 12 | east london
# Processing Record 6 of Set 12 | kruisfontein
# Processing Record 7 of Set 12 | shalqar
# Processing Record 8 of Set 12 | puerto carreno
# Processing Record 9 of Set 12 | oodweyne
# Processing Record 10 of Set 12 | zhezqazghan
# Processing Record 11 of Set 12 | portland
# Processing Record 12 of Set 12 | khanpur
# Processing Record 13 of Set 12 | saint-paul
# Processing Record 14 of Set 12 | paradip garh
# Processing Record 15 of Set 12 | monjaras
# Processing Record 16 of Set 12 | winnemucca
# Processing Record 17 of Set 12 | caburan
# Processing Record 18 of Set 12 | dzhalagash
# Processing Record 19 of Set 12 | tailai
# Processing Record 20 of Set 12 | mahriz
# Processing Record 21 of Set 12 | apia
# Processing Record 22 of Set 12 | banaz
# Processing Record 23 of Set 12 | vredendal
# Processing Record 24 of Set 12 | brooks
# Processing Record 25 of Set 12 | hadibu
# Processing Record 26 of Set 12 | takestan
# Processing Record 27 of Set 12 | puchezh
# Processing Record 28 of Set 12 | lerwick
# Processing Record 29 of Set 12 | shingu
# Processing Record 30 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 31 of Set 12 | acapulco de juarez
# Processing Record 32 of Set 12 | san carlos
# Processing Record 33 of Set 12 | makurazaki
# Processing Record 34 of Set 12 | smithers
# Processing Record 35 of Set 12 | tual
# Processing Record 36 of Set 12 | muisne
# Processing Record 37 of Set 12 | san jose del guaviare
# Processing Record 38 of Set 12 | saratamata
# City not found. Skipping...
# Processing Record 39 of Set 12 | tranovaho
# City not found. Skipping...
# Processing Record 40 of Set 12 | neya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

#def convert_fahrenheit_to_celsius(fahrenheit):
city_data_df["Max Temp"] = (city_data_df["Max Temp"]-32)*5/9

# Show Record Count
city_data_df.count()
# Out:
# City          556
# Lat           556
# Lng           556
# Max Temp      556
# Humidity      556
# Cloudiness    556
# Wind Speed    556
# Country       556
# Date          556
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#        City      Lat       Lng    Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      afif  23.9065   42.9172  154.950000         8           0        2.72
# 1   mek'ele  13.4967   39.4753  146.655556        49          69        5.41
# 2  waitangi -43.9535 -176.5597  138.238889        96          48        0.89
# 3    mahina -17.5065 -149.4890  147.166667        78           6       11.19
# 4   college  64.8569 -147.8028  141.400000        75          96        0.89
#
#   Country        Date
# 0      SA  1720099285
# 1      ET  1720099287
# 2      NZ  1720099289
# 3      PF  1720099291
# 4      US  1720099269

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng    Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            afif  23.9065   42.9172  154.950000         8           0
# 1         mek'ele  13.4967   39.4753  146.655556        49          69
# 2        waitangi -43.9535 -176.5597  138.238889        96          48
# 3          mahina -17.5065 -149.4890  147.166667        78           6
# 4         college  64.8569 -147.8028  141.400000        75          96
#
#          Wind Speed Country        Date
# City_ID
# 0              2.72      SA  1720099285
# 1              5.41      ET  1720099287
# 2              0.89      NZ  1720099289
# 3             11.19      PF  1720099291
# 4              0.89      US  1720099269

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

scatr_plotx=city_data_df["Lat"]
scatr_ploty=city_data_df["Max Temp"]
#scatr_ploty = float(city_data_df["Max Temp"] - 32) * 5 / 9
plt.scatter(scatr_plotx,scatr_ploty,marker="o", facecolors="blue")
plt.grid(True)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.suptitle('City Max Temperature vs Latitude')
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE
scatr_plotx=city_data_df["Lat"]
scatr_ploty=city_data_df["Humidity"]
plt.scatter(scatr_plotx,scatr_ploty,marker="o", facecolors="blue")
plt.grid(True)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.suptitle('City Latitude vs. Humidity')
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
scatr_plotx=city_data_df["Lat"]
scatr_ploty=city_data_df["Cloudiness"]
plt.scatter(scatr_plotx,scatr_ploty,marker="o", facecolors="blue")
plt.grid(True)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.suptitle('City Latitude vs. Cloudiness')
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
scatr_plotx=city_data_df["Lat"]
scatr_ploty=city_data_df["Wind Speed"]
plt.scatter(scatr_plotx,scatr_ploty,marker="o", facecolors="blue")
plt.grid(True)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.suptitle('City Latitude vs. Wind Speed')
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df= city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#             City      Lat       Lng    Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           afif  23.9065   42.9172  154.950000         8           0
# 1        mek'ele  13.4967   39.4753  146.655556        49          69
# 4        college  64.8569 -147.8028  141.400000        75          96
# 5          tiksi  71.6872  128.8694  135.472222        91         100
# 6         saipan  15.1355  145.7010  150.083333        74         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.72      SA  1720099285
# 1              5.41      ET  1720099287
# 4              0.89      US  1720099269
# 5              4.14      RU  1720099294
# 6              6.39      MP  1720099296

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df= city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat       Lng    Max Temp  Humidity  Cloudiness  \
# City_ID
# 2           waitangi -43.9535 -176.5597  138.238889        96          48
# 3             mahina -17.5065 -149.4890  147.166667        78           6
# 8           moranbah -22.0016  148.0466  142.205556        83          15
# 9          adamstown -25.0660 -130.1015  145.194444        69         100
# 14       antofagasta -23.6500  -70.4000  142.083333        62           0
#
#          Wind Speed Country        Date
# City_ID
# 2              0.89      NZ  1720099289
# 3             11.19      PF  1720099291
# 8              7.32      AU  1720099300
# 9              4.04      PN  1720099302
# 14             0.81      CL  1720099311

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

lr_nh_plotx=northern_hemi_df["Lat"]
lr_nh_ploty=northern_hemi_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(lr_nh_plotx,lr_nh_ploty)
lr_values = lr_nh_plotx * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
plt.scatter(lr_nh_plotx,lr_nh_ploty)
plt.plot(lr_nh_plotx,lr_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Max temp")
print(f"The r-value is {rvalue**2}")
plt.annotate(line_eq,(40,155),fontsize=15,color="red")
plt.suptitle('Latitude vs. Temperature')
#plt.tight_layout()
plt.show()
# Out:
# The r-value is 0.3561976278543472

# %%
# Linear regression on Southern Hemisphere
lr_sh_plotx=southern_hemi_df["Lat"]
lr_sh_ploty=southern_hemi_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(lr_sh_plotx,lr_sh_ploty)
lr_values = lr_sh_plotx * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
plt.scatter(lr_sh_plotx,lr_sh_ploty)
plt.plot(lr_sh_plotx,lr_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Max temp")
print(f"The r-value is {rvalue**2}")
plt.annotate(line_eq,(-55,152),fontsize=15,color="red")
plt.suptitle('Latitude vs. Temperature')
#plt.tight_layout()
plt.show()
# Out:
# The r-value is 0.7477967569549667

# %% [markdown]
# **Discussion about the linear relationship:
# It is observed that as the latitude increases, the temperature seems to be increasing gradually. But when the latitude is between 20-30, the temperature has shot more than the normal trend. It is also noted that in the southern hemisphere, the model takes in to consideration about 69.7% data where as the northern hemisphere data is around 35% of data for mapping the trend.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lh_nh_plotx=northern_hemi_df["Lat"]
lh_nh_ploty=northern_hemi_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(lh_nh_plotx,lh_nh_ploty)
lr_values = lh_nh_plotx * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
plt.scatter(lh_nh_plotx,lh_nh_ploty)
plt.plot(lh_nh_plotx,lr_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f"The r-value is {rvalue**2}")
plt.annotate(line_eq,(45,10),fontsize=15,color="red")
plt.suptitle('Latitude vs. Humidity')
#plt.tight_layout()
plt.show()
# Out:
# The r-value is 2.743386550904764e-05

# %%
# Southern Hemisphere
lh_sh_plotx=southern_hemi_df["Lat"]
lh_sh_ploty=southern_hemi_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(lh_sh_plotx,lh_sh_ploty)
lr_values = lh_sh_plotx * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
plt.scatter(lh_sh_plotx,lh_sh_ploty)
plt.plot(lh_sh_plotx,lr_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f"The r-value is {rvalue**2}")
plt.annotate(line_eq,(-55,15),fontsize=15,color="red")
plt.suptitle('Latitude vs. Humidity')
#plt.tight_layout()
plt.show()
# Out:
# The r-value is 0.0032782520484390875

# %% [markdown]
# **Discussion about the linear relationship:
# It is observed that the humidity almost remained constant with the change in latitude across northern and southern hemispheres for the cities that are selected in the dataset. It is also noted that humidity is 80-100 for the cities that are in the latitude of -10 and 0

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

lc_nh_plotx=northern_hemi_df["Lat"]
lc_nh_ploty=northern_hemi_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(lc_nh_plotx,lc_nh_ploty)
lr_values = lc_nh_plotx * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
plt.scatter(lc_nh_plotx,lc_nh_ploty)
plt.plot(lc_nh_plotx,lr_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f"The r-value is {rvalue**2}")
plt.annotate(line_eq,(0,5),fontsize=15,color="red")
plt.suptitle('Latitude vs. Cloudiness')
#plt.tight_layout()
plt.show()
# Out:
# The r-value is 0.0002717536386117002

# %%
# Southern Hemisphere

lc_sh_plotx=southern_hemi_df["Lat"]
lc_sh_ploty=southern_hemi_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(lc_sh_plotx,lc_sh_ploty)
lr_values = lc_sh_plotx * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
plt.scatter(lc_sh_plotx,lc_sh_ploty)
plt.plot(lc_sh_plotx,lr_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f"The r-value is {rvalue**2}")
plt.annotate(line_eq,(-55,20),fontsize=15,color="red")
plt.suptitle('Latitude vs. Cloudiness')
#plt.tight_layout()
plt.show()
# Out:
# The r-value is 0.06476358273974378

# %% [markdown]
# **Discussion about the linear relationship:
# It is observed that the cloudiness in southern hemisphere is more in the latitude between -10 and 0 but the cloudiness line remained more or less constant at different latitudes. Also the cloudiness seems to be more in northern hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

lw_nh_plotx=northern_hemi_df["Lat"]
lw_nh_ploty=northern_hemi_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(lw_nh_plotx,lw_nh_ploty)
lr_values = lc_nh_plotx * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
plt.scatter(lw_nh_plotx,lw_nh_ploty)
plt.plot(lw_nh_plotx,lr_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f"The r-value is {rvalue**2}")
plt.annotate(line_eq,(40,13),fontsize=15,color="red")
plt.suptitle('Latitude vs. Wind Speed')
#plt.tight_layout()
plt.show()
# Out:
# The r-value is 0.0021284917253454974

# %%
# Southern Hemisphere

lw_sh_plotx=southern_hemi_df["Lat"]
lw_sh_ploty=southern_hemi_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(lw_sh_plotx,lw_sh_ploty)
lr_values = lw_sh_plotx * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
plt.scatter(lw_sh_plotx,lw_sh_ploty)
plt.plot(lw_sh_plotx,lr_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f"The r-value is {rvalue**2}")
plt.annotate(line_eq,(-50,13),fontsize=15,color="red")
plt.suptitle('Latitude vs. Wind Speed')
#plt.tight_layout()
plt.show()
# Out:
# The r-value is 0.02506169825548702

# %% [markdown]
# **Discussion about the linear relationship:
# The windspeed is more in northern hemispehere compared to southern hemispere but the overall windspeed is constant with the change in latitude for both the hemispeheres.
